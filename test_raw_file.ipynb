# %%
import rawpy
import numpy as np
import matplotlib.pyplot as plt

rawImg = rawpy.imread('test_images/IMG_3695.CR2')
rgbImg = rawImg.postprocess()
print(type(rgbImg))
print(rgbImg[0])

plt.figure()
plt.imshow(rgbImg)
plt.show()
# Out:
# <class 'numpy.ndarray'>
# [2087 2092 2110 ... 2217 2155 2279]

# %%
print('hello world')
# Out:
# hello world
